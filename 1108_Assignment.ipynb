# %% [markdown]
# <a href="https://colab.research.google.com/github/shriver42/ESAA/blob/%ED%95%84%EC%82%AC-%EA%B3%BC%EC%A0%9C/1108_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **01. 딥러닝 준비**
#
# **주요 용어**
#
# 1. 하이퍼파라미터 : 사용자가 직접 설정해야하는 값
# 2. 과소적합(underfitting) vs 과대적합(overfitting)
#   - 과소적합: 모델이 충분히 학습되지 않아 예측 성능이 떨어진 상태
#   - 과대 적합: 학습 데이터를 지나치게 반복 학습하게 되어 과하게 적합된 상태
# 3. 에포크: 모델 반복 훈련 시 데이터셋이 전부 학습에 사용되는 1회의 루프
#   - 과소적합: 에포크 늘려서 다시 학습시키기
#   - 과대적합: 에포크 줄여서 최적 구간에서 학습 종료
# 4. 손실함수: 예측 값과 정답 값의 차이 또는 오차(Error)
#   - 이진 분류: binary_crossentropy 손실함수 사용
#   - 다중 분류
#     - 원핫 벡터인 경우 :: categorical_crossentropy 손실함수
#     - 레이블 값인 경우 : sparse_categorical_crossentropy 손실함수
#     - 출력층의 활성화 함수 : softmax
# 5. 경사하강법: 모델을 훈련시, 모델 내부의 가중치에 대한 미분 값을 구하고 목적 함수 값이 낮아지는 방향으로 차감하면서 결국 최소 함수 값을 갖도록 함

# %%
# 클래스 및 함수 형태로 정의되어 있는 손실함수를 지정하여 사용
import tensorflow as tf

# 클래스
tf.keras.losses.BinaryCrossentropy()

# 함수
tf.keras.losses.binary_crossentropy
# Out:
# <function keras.src.losses.losses.binary_crossentropy(y_true, y_pred, from_logits=False, label_smoothing=0.0, axis=-1)>

# %%
# 단순 선형회귀 수식(y=wx+b)이 주어졌을 때, 손실함수를 최소로 하는 w와 b를 구하는 과정을 경사하강법으로 구현
import numpy as np
import matplotlib.pyplot as plt

# 샘플에 활용할 데이터셋 만들기
def make_linear(w = 0.5, b = 0.8, size = 50, noise = 1.0):
  x = np.random.rand(size)
  y = w * x + b
  noise = np.random.uniform(-abs(noise), abs(noise), size = y.shape)
  yy = y + noise
  plt.figure(figsize = (10,7))
  plt.plot(x, y, color = 'r', label = f'y = {w}*x + {b}')
  plt.scatter(x, yy, label='data')
  plt.legend(fontsize=20)
  plt.show()
  print(f'w:{w}, b:{b}')
  return x, yy

x, y = make_linear(w = 0.3, b = 0.5, size = 100, noise = 0.01)
# Out:
# w:0.3, b:0.5

# %%
# 최대 반복 횟수
num_epoch = 1000

# 학습률(learning_rate)
learning_rate = 0.005

# 에러 기록
errors = []

# random 한 값으로 w,b를 초기화
w = np.random.uniform(low=0.0, high=1.0)
b = np.random.uniform(low=0.0, high=1.0)

for epoch in range(num_epoch):
  # Hypothesis 정의
  y_hat = w * x + b

  # Loss Function 정의
  error = 0.5*((y_hat-y)**2).sum()
  if error < 0.005:
    break
  # Gradient 미분 계산
  w = w - learning_rate * ((y_hat-y)*x).sum()
  b = b - learning_rate * (y_hat-y).sum()

  errors.append(error)

  if epoch % 5 == 0:
    print("{0:2} w = {1:.5f}, b = {2:.5f} error = {3:.5f}".format(epoch, w, b, error))

print("----" * 15)
print("{0:2} w = {1:.1f}, b = {2:.1f} error = {3:.5f}".format(epoch, w, b, error))
# Out:
#  0 w = 0.33923, b = 0.50987 error = 0.51177
# ------------------------------------------------------------
#  3 w = 0.3, b = 0.5 error = 0.00489

# %%
plt.figure(figsize=(10,7))
plt.plot(errors)
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# 1-2 딥러닝 프로세스
#
# ![화면 캡처 2024-11-09 160442.png](data:image/png;base64,...)

# %% [markdown]
# ### **02. 단순 신경망 훈련**
#
# 2-1 선형회귀
# - 단순선형회귀 모형: 하나의 X가 Y에 미치는 영향 추정
# - Y = wX + b
#   - X: 독립변수 Y: 종속변수 w: 가중치 b: 편향
#
# 2-1 뉴런
# - 뉴런: node라고도 불리며, 인공 신경망 모델을 구성하는 하나의 신경을 의미함.
# - 신경망: 여러 개의 레이어를 가지며 1개의 레이어는 1개 이상의 뉴런으로 구성됨.
# - 뉴런의 내부에는 가중치가 존재하며, 모델이 훈련을 진행하면서 오차 역전파를 통해 뉴런의 가중치가 업데이트됨.
#
# 2-3. Dense 레이어
# - 심층 신경망 모델을 구성하는 가장 기본 레이어

# %%
import tensorflow as tf

# 10개의 노드로 이루어진 Dense 레이어
tf.keras.layers.Dense(10)

# ReLU 활성화 함수 적용
tf.keras.layers.Dense(10, activation='relu')
# Out:
# <Dense name=dense_1, built=False>

# %% [markdown]
# 2-4 데이터셋 만들기

# %%
# 샘플 데이터셋 생성
x = np.arange(1,6)

# y = 3x + 2
y = 3*x + 2
print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [ 5  8 11 14 17]

# %%
import matplotlib.pyplot as plt

# 시각화
plt.plot(x, y)
plt.title('y = 3x + 2')
plt.show()

# %% [markdown]
# 2-5 Sequential API
# - Sequential API 방식 : 층을 이어 붙이듯 시퀀스에 맞게 일렬로 연결하는 방식
# - 케라스의 Sequential API를 사용하면 매우 간결하게 딥러닝 모델을 만들 수 있음.
# - 2개 이상의 입력(다중 입력)이나 2개 이상의 출력(다중 출력)을 갖는 복잡한 구조를 만들 수 없어 이런 경우  Functional API를 사용해야 함.
#
#   2-5-1 모델구조
#   - Sequential 클래스 함수에 파이썬 리스트 형태로 여러 개의 층을 입력
#   - 대괄호 안에 쉼표로 구분하여 층 쌓기
#   - add() : 레이어 추가
#
#   2-5-2 입력 데이터 형태
#   - 첫번째 층은 반드시 input_shape 매개변수를 지정해야 함.
#      - input_shape : 데이터셋의 shape를 tuple 또는 list로 지정할 수 있음.
#
#   2-5-3 단순 선형 회귀 모델 정의
#   - 1개의 뉴런을 가지는 Dense layer를 한 개 사용
#     - input_layer : [1]로 지정
#   - 1개의 뉴런을 가지는 Dense layer는 1개의 출력값을 가지므로 출력값은 y에 대한 모델의 예측값

# %%
import tensorflow as tf

# 리스트형
model = tf.keras.Sequential([
        tf.keras.layers.Dense(10),
        tf.keras.layers.Dense(5),
        tf.keras.layers.Dense(1)
])

# %%
# add 함수로 레이어 추가
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(10))
model.add(tf.keras.layers.Dense(5))
model.add(tf.keras.layers.Dense(1))

# %%
import tensorflow as tf

model = tf.keras.Sequential([
  # 입력 데이터의 shape = (150, 4)인 경우
  tf.keras.layers.Dense(10, input_shape = [4]),
  tf.keras.layers.Dense(5),
  tf.keras.layers.Dense(1)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 단순선형회귀 모델 생성
model = tf.keras.Sequential([
        tf.keras.layers.Dense(1, input_shape=[1])
])

# %% [markdown]
# 2-6 모델 요약
# - Total params : 모델 내부에 존재하는 모든 파라미터의 합계
# - Trainable params : 모델 훈련 시 업데이트할 파라미터의 총 개수
# - Non-trainable params : 모델 훈련 시 업데이트하지 않을 파라미터의 총 개수

# %%
# 모델 요약
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_11 (Dense)                     │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 2-7 컴파일
# - 모델의 훈련 과정에서 적용할 옵티마이저(optimizer), 손실함수(loss), 평가지표(metric) 등을 정의함.

# %%
# 긴 문자열 지정
model.compile(optimizer='sgd', loss='mean_squared_error',
              metrics=['mean_squared_error', 'mean_absolute_error'])

# %%
# 짧은 문자열 지정
model.compile(optimizer='sgd', loss='mse', metrics=['mse', 'mae'])

# %%
# 클래스 인스턴스 지정
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.005),
              loss=tf.keras.losses.MeanAbsoluteError(),
              metrics=[tf.keras.metrics.MeanAbsoluteError(),
                       tf.keras.metrics.MeanSquaredError()
              ])

# %% [markdown]
# - optimizer: sgd(확률적 경사 하강법)
# - 손실 함수: mse
# - 평가 지표: mae

# %%
# 컴파일
model.compile(optimizer='sgd', loss='mse', metrics=['mae'])

# %% [markdown]
# 2-8 훈련
# - 생성된 모델 인스턴스에 fit() 함수로 훈련
#   - fit() : 입력(x), 출력(y), epoch 수 지정
# - 매 epoch가 끝날 때마다 훈련 데이터셋에 대한 손실과 평가지표 출력
# - validation_data 지정했을 경우 검증 셋에 대한 손실과 평가 지표도 함께 출력함.

# %%
# 훈련
model.fit(x, y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step - loss: 71.5957 - mae: 7.9783
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 41.8576 - mae: 6.1435
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 24.5267 - mae: 4.7427
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 14.4263 - mae: 3.6731
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 8.5394 - mae: 2.8565

# %%
# 단순선형회귀 모델 생성
model = tf.keras.Sequential([
        tf.keras.layers.Dense(1, input_shape=[1])
])

# 컴파일
model.compile(optimizer='sgd', loss='mse', metrics=['mae'])

# 훈련
history = model.fit(x, y, epochs = 1200)
# Out:
# Epoch 1/1200
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 37.6865 - mae: 5.8627
# Epoch 2/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 22.1359 - mae: 4.5356
# Epoch 3/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13.0726 - mae: 3.5224
# Epoch 4/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.7898 - mae: 2.7487
# Epoch 5/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.7100 - mae: 2.1579
# Epoch 6/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.9142 - mae: 1.7066
# Epoch 7/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.8665 - mae: 1.3620
# Epoch 8/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2548 - mae: 1.0987
# Epoch 9/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8972 - mae: 0.8975
# Epoch 10/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.6877 - mae: 0.7437
# Epoch 11/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5645 - mae: 0.6261
# Epoch 12/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4916 - mae: 0.5773
# Epoch 13/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4481 - mae: 0.5515
# Epoch 14/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4216 - mae: 0.5314
# Epoch 15/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4051 - mae: 0.5157
# Epoch 16/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3944 - mae: 0.5150
# Epoch 17/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3871 - mae: 0.5170
# Epoch 18/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3817 - mae: 0.5182
# Epoch 19/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3776 - mae: 0.5186
# Epoch 20/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3741 - mae: 0.5186
# Epoch 21/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3711 - mae: 0.5181
# Epoch 22/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3682 - mae: 0.5173
# Epoch 23/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3656 - mae: 0.5163
# Epoch 24/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.
1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1387 - mae: 0.3196
# Epoch 167/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1377 - mae: 0.3186
# Epoch 168/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1368 - mae: 0.3175
# Epoch 169/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1359 - mae: 0.3164
# Epoch 170/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1350 - mae: 0.3153
# Epoch 171/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1341 - mae: 0.3143
# Epoch 172/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.1332 - mae: 0.3132
# Epoch 173/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.1323 - mae: 0.3121
# Epoch 174/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1314 - mae: 0.3111
# Epoch 175/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1305 - mae: 0.3100
# Epoch 176/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1296 - mae: 0.3090
# Epoch 177/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1287 - mae: 0.3079
# Epoch 178/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1279 - mae: 0.3069
# Epoch 179/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1270 - mae: 0.3059
# Epoch 180/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1261 - mae: 0.3048
# Epoch 181/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1253 - mae: 0.3038
# Epoch 182/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1244 - mae: 0.3028
# Epoch 183/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1236 - mae: 0.3018
# Epoch 184/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1228 - mae: 0.3007
# Epoch 185/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.1219 - mae: 0.2997
# Epoch 186/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1211 - mae: 0.2987
# Epoch 187/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1203 - mae: 0.2977
# Epoch 188/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1195 - mae: 0.2967
# Epoch 189/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1187 - mae: 0.2957
# Epoch 190/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1179 - mae: 0.2947
# Epoch 191/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1171 - mae: 0.2937
# Epoch 192/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1163 - mae: 0.2927
# Epoch 193/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1155 - mae: 0.2917
# Epoch 194/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1147 - mae: 0.2907
# Epoch 195/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1139 - mae: 0.2897
# Epoch 196/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1132 - mae: 0.2888
# Epoch 197/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1124 - mae: 0.2878
# Epoch 198/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1117 - mae: 0.2868
# Epoch 199/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.1109 - mae: 0.2858
# Epoch 200/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1102 - mae: 0.2849
# Epoch 201/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.1094 - mae: 0.2839
# Epoch 202/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1087 - mae: 0.2829
# Epoch 203/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1079 - mae: 0.2820
# Epoch 204/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1072 - mae: 0.2810
# Epoch 205/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1065 - mae: 0.2801
# Epoch 206/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1058 - mae: 0.2791
# Epoch 207/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1051 - mae: 0.2782
# Epoch 208/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1043 - mae: 0.2773
# Epoch 209/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1036 - mae: 0.2763
# Epoch 210/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1029 - mae: 0.2754
# Epoch 211/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1022 - mae: 0.2745
# Epoch 212/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1016 - mae: 0.2735
# Epoch 213/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1009 - mae: 0.2726
# Epoch 214/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1002 - mae: 0.2717
# Epoch 215/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0995 - mae: 0.2708
# Epoch 216/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0988 - mae: 0.2698
# Epoch 217/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0982 - mae: 0.2689
# Epoch 218/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0975 - mae: 0.2680
# Epoch 219/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0968 - mae: 0.2671
# Epoch 220/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0962 - mae: 0.2662
# Epoch 221/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0955 - mae: 0.2653
# Epoch 222/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0949 - mae: 0.2644
# Epoch 223/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0943 - mae: 0.2635
# Epoch 224/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0936 - mae: 0.2626
# Epoch 225/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0930 - mae: 0.2617
# Epoch 226/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0924 - mae: 0.2609
# Epoch 227/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0917 - mae: 0.2600
# Epoch 228/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0911 - mae: 0.2591
# Epoch 229/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0905 - mae: 0.2582
# Epoch 230/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0899 - mae: 0.2573
# Epoch 231/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0893 - mae: 0.2565
# Epoch 232/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0887 - mae: 0.2556
# Epoch 233/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0881 - mae: 0.2547
# Epoch 234/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0875 - mae: 0.2539
# Epoch 235/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0869 - mae: 0.2530
# Epoch 236/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0863 - mae: 0.2522
# Epoch 237/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0857 - mae: 0.2513
# Epoch 238/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0852 - mae: 0.2505
# Epoch 239/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0846 - mae: 0.2496
# Epoch 240/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0840 - mae: 0.2488
# Epoch 241/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0834 - mae: 0.2479
# Epoch 242/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0829 - mae: 0.2471
# Epoch 243/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0823 - mae: 0.2463
# Epoch 244/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0818 - mae: 0.2454
# Epoch 245/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0812 - mae: 0.2446
# Epoch 246/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0807 - mae: 0.2438
# Epoch 247/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0801 - mae: 0.2429
# Epoch 248/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0796 - mae: 0.2421
# Epoch 249/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0790 - mae: 0.2413
# Epoch 250/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0785 - mae: 0.2405
# Epoch 251/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0780 - mae: 0.2397
# Epoch 252/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0775 - mae: 0.2389
# Epoch 253/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0769 - mae: 0.2381
# Epoch 254/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0764 - mae: 0.2373
# Epoch 255/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0759 - mae: 0.2365
# Epoch 256/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0754 - mae: 0.2357
# Epoch 257/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0749 - mae: 0.2349
# Epoch 258/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0744 - mae: 0.2341
# Epoch 259/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0739 - mae: 0.2333
# Epoch 260/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0734 - mae: 0.2325
# Epoch 261/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0729 - mae: 0.2317
# Epoch 262/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0724 - mae: 0.2309
# Epoch 263/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0719 - mae: 0.2301
# Epoch 264/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0714 - mae: 0.2294
# Epoch 265/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0709 - mae: 0.2286
# Epoch 266/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0704 - mae: 0.2278
# Epoch 267/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0700 - mae: 0.2270
# Epoch 268/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0695 - mae: 0.2263
# Epoch 269/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0690 - mae: 0.2255
# Epoch 270/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0686 - mae: 0.2247
# Epoch 271/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0681 - mae: 0.2240
# Epoch 272/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0676 - mae: 0.2232
# Epoch 273/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0672 - mae: 0.2225
# Epoch 274/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0667 - mae: 0.2217
# Epoch 275/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0663 - mae: 0.2210
# Epoch 276/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0658 - mae: 0.2202
# Epoch 277/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0654 - mae: 0.2195
# Epoch 278/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0649 - mae: 0.2187
# Epoch 279/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0645 - mae: 0.2180
# Epoch 280/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0641 - mae: 0.2173
# Epoch 281/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0636 - mae: 0.2165
# Epoch 282/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0632 - mae: 0.2158
# Epoch 283/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0628 - mae: 0.2151
# Epoch 284/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0624 - mae: 0.2143
# Epoch 285/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0619 - mae: 0.2136
# Epoch 286/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0615 - mae: 0.2129
# Epoch 287/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0611 - mae: 0.2122
# Epoch 288/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0607 - mae: 0.2115
# Epoch 289/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0603 - mae: 0.2107
# Epoch 290/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0599 - mae: 0.2100
# Epoch 291/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0595 - mae: 0.2093
# Epoch 292/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0591 - mae: 0.2086
# Epoch 293/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0587 - mae: 0.2079
# Epoch 294/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0583 - mae: 0.2072
# Epoch 295/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0579 - mae: 0.2065
# Epoch 296/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0575 - mae: 0.2058
# Epoch 297/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0571 - mae: 0.2051
# Epoch 298/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0567 - mae: 0.2044
# Epoch 299/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0563 - mae: 0.2037
# Epoch 300/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0560 - mae: 0.2030
# Epoch 301/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0556 - mae: 0.2023
# Epoch 302/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0552 - mae: 0.2017
# Epoch 303/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0548 - mae: 0.2010
# Epoch 304/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0545 - mae: 0.2003
# Epoch 305/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0541 - mae: 0.1996
# Epoch 306/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0537 - mae: 0.1989
# Epoch 307/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0534 - mae: 0.1983
# Epoch 308/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.
1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0325 - mae: 0.1548
# Epoch 381/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0323 - mae: 0.1543
# Epoch 382/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0321 - mae: 0.1538
# Epoch 383/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0319 - mae: 0.1533
# Epoch 384/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0317 - mae: 0.1528
# Epoch 385/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0315 - mae: 0.1522
# Epoch 386/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0312 - mae: 0.1517
# Epoch 387/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0310 - mae: 0.1512
# Epoch 388/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0308 - mae: 0.1507
# Epoch 389/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0306 - mae: 0.1502
# Epoch 390/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0304 - mae: 0.1497
# Epoch 391/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0302 - mae: 0.1492
# Epoch 392/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0300 - mae: 0.1487
# Epoch 393/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0298 - mae: 0.1482
# Epoch 394/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0296 - mae: 0.1477
# Epoch 395/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0294 - mae: 0.1472
# Epoch 396/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0292 - mae: 0.1467
# Epoch 397/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0290 - mae: 0.1462
# Epoch 398/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0288 - mae: 0.1457
# Epoch 399/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0286 - mae: 0.1452
# Epoch 400/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0284 - mae: 0.1447
# Epoch 401/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0282 - mae: 0.1442
# Epoch 402/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0280 - mae: 0.1437
# Epoch 403/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0279 - mae: 0.1432
# Epoch 404/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0277 - mae: 0.1428
# Epoch 405/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0275 - mae: 0.1423
# Epoch 406/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0273 - mae: 0.1418
# Epoch 407/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0271 - mae: 0.1413
# Epoch 408/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0269 - mae: 0.1408
# Epoch 409/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0267 - mae: 0.1404
# Epoch 410/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0266 - mae: 0.1399
# Epoch 411/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0264 - mae: 0.1394
# Epoch 412/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0262 - mae: 0.1389
# Epoch 413/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0260 - mae: 0.1385
# Epoch 414/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0259 - mae: 0.1380
# Epoch 415/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0257 - mae: 0.1375
# Epoch 416/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0255 - mae: 0.1371
# Epoch 417/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0253 - mae: 0.1366
# Epoch 418/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0252 - mae: 0.1361
# Epoch 419/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0250 - mae: 0.1357
# Epoch 420/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0248 - mae: 0.1352
# Epoch 421/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0247 - mae: 0.1348
# Epoch 422/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0245 - mae: 0.1343
# Epoch 423/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0243 - mae: 0.1339
# Epoch 424/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0242 - mae: 0.1334
# Epoch 425/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0240 - mae: 0.1330
# Epoch 426/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0238 - mae: 0.1325
# Epoch 427/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0237 - mae: 0.1321
# Epoch 428/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0235 - mae: 0.1316
# Epoch 429/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0234 - mae: 0.1312
# Epoch 430/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0232 - mae: 0.1307
# Epoch 431/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0230 - mae: 0.1303
# Epoch 432/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0229 - mae: 0.1298
# Epoch 433/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0227 - mae: 0.1294
# Epoch 434/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0226 - mae: 0.1290
# Epoch 435/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0224 - mae: 0.1285
# Epoch 436/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0223 - mae: 0.1281
# Epoch 437/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0221 - mae: 0.1277
# Epoch 438/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0220 - mae: 0.1272
# Epoch 439/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0218 - mae: 0.1268
# Epoch 440/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0217 - mae: 0.1264
# Epoch 441/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0215 - mae: 0.1259
# Epoch 442/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0214 - mae: 0.1255
# Epoch 443/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0212 - mae: 0.1251
# Epoch 444/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0211 - mae: 0.1247
# Epoch 445/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0210 - mae: 0.1242
# Epoch 446/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0208 - mae: 0.1238
# Epoch 447/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0207 - mae: 0.1234
# Epoch 448/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0205 - mae: 0.1230
# Epoch 449/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0204 - mae: 0.1226
# Epoch 450/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0203 - mae: 0.1222
# Epoch 451/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0201 - mae: 0.1218
# Epoch 452/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0200 - mae: 0.1213
# Epoch 453/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0198 - mae: 0.1209
# Epoch 454/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0197 - mae: 0.1205
# Epoch 455/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0196 - mae: 0.1201
# Epoch 456/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0195 - mae: 0.1197
# Epoch 457/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0193 - mae: 0.1193
# Epoch 458/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0192 - mae: 0.1189
# Epoch 459/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0191 - mae: 0.1185
# Epoch 460/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0189 - mae: 0.1181
# Epoch 461/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0188 - mae: 0.1177
# Epoch 462/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0187 - mae: 0.1173
# Epoch 463/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.0185 - mae: 0.1169
# Epoch 464/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0184 - mae: 0.1165
# Epoch 465/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0183 - mae: 0.1161
# Epoch 466/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0182 - mae: 0.1157
# Epoch 467/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0181 - mae: 0.1153
# Epoch 468/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0179 - mae: 0.1149
# Epoch 469/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0178 - mae: 0.1146
# Epoch 470/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0177 - mae: 0.1142
# Epoch 471/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0176 - mae: 0.1138
# Epoch 472/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0175 - mae: 0.1134
# Epoch 473/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0173 - mae: 0.1130
# Epoch 474/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0172 - mae: 0.1126
# Epoch 475/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0171 - mae: 0.1122
# Epoch 476/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0170 - mae: 0.1119
# Epoch 477/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0169 - mae: 0.1115
# Epoch 478/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0168 - mae: 0.1111
# Epoch 479/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0166 - mae: 0.1107
# Epoch 480/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0165 - mae: 0.1104
# Epoch 481/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0164 - mae: 0.1100
# Epoch 482/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0163 - mae: 0.1096
# Epoch 483/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0162 - mae: 0.1092
# Epoch 484/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0161 - mae: 0.1089
# Epoch 485/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0160 - mae: 0.1085
# Epoch 486/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0159 - mae: 0.1081
# Epoch 487/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0158 - mae: 0.1078
# Epoch 488/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0157 - mae: 0.1074
# Epoch 489/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0156 - mae: 0.1070
# Epoch 490/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0154 - mae: 0.1067
# Epoch 491/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0153 - mae: 0.1063
# Epoch 492/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0152 - mae: 0.1060
# Epoch 493/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0151 - mae: 0.1056
# Epoch 494/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0150 - mae: 0.1053
# Epoch 495/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0149 - mae: 0.1049
# Epoch 496/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0148 - mae: 0.1045
# Epoch 497/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0147 - mae: 0.1042
# Epoch 498/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0146 - mae: 0.1038
# Epoch 499/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0145 - mae: 0.1035
# Epoch 500/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0144 - mae: 0.1031
# Epoch 501/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0143 - mae: 0.1028
# Epoch 502/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0142 - mae: 0.1024
# Epoch 503/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0141 - mae: 0.1021
# Epoch 504/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0141 - mae: 0.1017
# Epoch 505/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0140 - mae: 0.1014
# Epoch 506/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0139 - mae: 0.1011
# Epoch 507/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0138 - mae: 0.1007
# Epoch 508/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0137 - mae: 0.1004
# Epoch 509/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0136 - mae: 0.1000
# Epoch 510/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0135 - mae: 0.0997
# Epoch 511/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0134 - mae: 0.0994
# Epoch 512/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0133 - mae: 0.0990
# Epoch 513/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0132 - mae: 0.0987
# Epoch 514/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0131 - mae: 0.0984
# Epoch 515/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0130 - mae: 0.0980
# Epoch 516/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0130 - mae: 0.0977
# Epoch 517/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0129 - mae: 0.0974
# Epoch 518/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0128 - mae: 0.0970
# Epoch 519/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0127 - mae: 0.0967
# Epoch 520/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0126 - mae: 0.0964
# Epoch 521/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0125 - mae: 0.0961
# Epoch 522/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0124 - mae: 0.0957
# Epoch 523/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0124 - mae: 0.0954
# Epoch 524/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0123 - mae: 0.0951
# Epoch 525/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0122 - mae: 0.0948
# Epoch 526/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0121 - mae: 0.0944
# Epoch 527/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0120 - mae: 0.0941
# Epoch 528/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0119 - mae: 0.0938
# Epoch 529/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0119 - mae: 0.0935
# Epoch 530/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0118 - mae: 0.0932
# Epoch 531/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0117 - mae: 0.0929
# Epoch 532/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0116 - mae: 0.0925
# Epoch 533/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0115 - mae: 0.0922
# Epoch 534/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0115 - mae: 0.0919
# Epoch 535/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0114 - mae: 0.0916
# Epoch 536/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0113 - mae: 0.0913
# Epoch 537/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0112 - mae: 0.0910
# Epoch 538/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0112 - mae: 0.0907
# Epoch 539/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0111 - mae: 0.0904
# Epoch 540/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0110 - mae: 0.0901
# Epoch 541/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0109 - mae: 0.0898
# Epoch 542/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0109 - mae: 0.0895
# Epoch 543/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0108 - mae: 0.0892
# Epoch 544/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0107 - mae: 0.0889
# Epoch 545/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0106 - mae: 0.0886
# Epoch 546/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0106 - mae: 0.0883
# Epoch 547/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0105 - mae: 0.0880
# Epoch 548/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0104 - mae: 0.0877
# Epoch 549/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0104 - mae: 0.0874
# Epoch 550/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0103 - mae: 0.0871
# Epoch 551/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0102 - mae: 0.0868
# Epoch 552/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0102 - mae: 0.0865
# Epoch 553/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0101 - mae: 0.0862
# Epoch 554/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0100 - mae: 0.0859
# Epoch 555/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0099 - mae: 0.0856
# Epoch 556/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0099 - mae: 0.0853
# Epoch 557/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0098 - mae: 0.0850
# Epoch 558/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0097 - mae: 0.0847
# Epoch 559/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0097 - mae: 0.0845
# Epoch 560/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0096 - mae: 0.0842
# Epoch 561/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0096 - mae: 0.0839
# Epoch 562/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0095 - mae: 0.0836
# Epoch 563/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0094 - mae: 0.0833
# Epoch 564/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0094 - mae: 0.0830
# Epoch 565/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0093 - mae: 0.0828
# Epoch 566/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0092 - mae: 0.0825
# Epoch 567/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0092 - mae: 0.0822
# Epoch 568/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0091 - mae: 0.0819
# Epoch 569/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0090 - mae: 0.0816
# Epoch 570/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0090 - mae: 0.0814
# Epoch 571/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0089 - mae: 0.0811
# Epoch 572/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0089 - mae: 0.0808
# Epoch 573/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0088 - mae: 0.0805
# Epoch 574/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0087 - mae: 0.0803
# Epoch 575/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0087 - mae: 0.0800
# Epoch 576/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0086 - mae: 0.0797
# Epoch 577/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0086 - mae: 0.0795
# Epoch 578/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0085 - mae: 0.0792
# Epoch 579/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0085 - mae: 0.0789
# Epoch 580/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0084 - mae: 0.0787
# Epoch 581/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0083 - mae: 0.0784
# Epoch 582/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0083 - mae: 0.0781
# Epoch 583/1200
# ...
# Epoch 1018/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.3226e-04 - mae: 0.0178
# Epoch 1019/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 4.2934e-04 - mae: 0.0178
# Epoch 1020/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 4.2644e-04 - mae: 0.0177
# Epoch 1021/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 4.2355e-04 - mae: 0.0177
# Epoch 1022/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 4.2069e-04 - mae: 0.0176
# Epoch 1023/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 4.1785e-04 - mae: 0.0175
# Epoch 1024/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 4.1504e-04 - mae: 0.0175
# Epoch 1025/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 4.1224e-04 - mae: 0.0174
# Epoch 1026/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 4
1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.2858e-04 - mae: 0.0097
# Epoch 1198/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.2771e-04 - mae: 0.0097
# Epoch 1199/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.2685e-04 - mae: 0.0097
# Epoch 1200/1200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.2600e-04 - mae: 0.0096

# %%
# history 변수를 사용하여 epoch별 훈련 손실 및 평가지표를 시각화
import matplotlib.pyplot as plt

# 20 epoch까지 Loss 수렴에 대한 시각화
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['mae'], label='mae')
plt.xlim(-1,20)
plt.title('Loss')
plt.legend()
plt.show()

# %% [markdown]
# 2-9 검증
# - evaluate() 를 통해 성능 검증

# %%
# 검증
model.evaluate(x, y)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 1.2514e-04 - mae: 0.0096
# [0.00012514462287072092, 0.009601974859833717]

# %% [markdown]
# 2-10 예측
# - predict() 에 새로운 입력 데이터 넣기

# %%
# 예측
model.predict(np.array([10]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# array([[32.04641]], dtype=float32)

# %% [markdown]
# ### **03. 심층 신경망으로 이미지 분류**
#
# 3-1 케라스 내장 데이터셋 로드
# - boston_housing : 보스톤 주택 가격 데이터셋 (회귀)
# - cifar10 : CIFAR10 이미지 분류 데이터셋 (분류)
# - cifar100 : CIFAR100 이미지 분류 데이터셋 (분류)
# - mnist : mnist 손글씨 데이터셋 (분류)
# - fashion_mnist : 의류 데이터셋 (분류)
# - imdb : IMDB 영화 데이터셋 (분류)
# - reuters : Reuters 뉴스 토픽 (분류)

# %%
import tensorflow as tf

# 케라스의 내장 데이터셋에서 mnist 데이터셋 로드
mnist = tf.keras.datasets.mnist

# %%
# load_data()로 데이터셋 로드
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# 로드된 데이터셋 확인
print('train set : ', x_train.shape, y_train.shape)
print('test set : ', x_test.shape, y_test.shape)
# Out:
# train set :  (60000, 28, 28) (60000,)
# test set :  (10000, 28, 28) (10000,)

# %%
#데이터 시각화
import matplotlib.pyplot as plt

# canvas 생성
fig, axes = plt.subplots(3, 5)
fig.set_size_inches(8, 5)

for i in range(15):
  ax = axes[i//5, i%5]

  # imshow로 이미지 시각화
  ax.imshow(x_train[i], cmap = 'gray')
  ax.axis('off')
  ax.set_title(str(y_train[i]))

plt.tight_layout()
plt.show()

# %% [markdown]
# 3-2 데이터 전처리
# - 기존 데이터: 0~255 -> 255로 나누어 0과 1사이의 값으로 정규화
#   - 정규화하여 학습하면 경사 하강법 알고리즘에 의한 수렴 속도가 더 빨라짐.
#   - local optimum 에 빠지는 현상 방지

# %%
# x_train 배열의 데이터 확인
x_train[0, 10:15, 10:15]
# Out:
# array([[  1, 154, 253,  90,   0],
#        [  0, 139, 253, 190,   2],
#        [  0,  11, 190, 253,  70],
#        [  0,   0,  35, 241, 225],
#        [  0,   0,   0,  81, 240]], dtype=uint8)

# %%
# 픽셀 값의 최소/최대값 확인
print(f'정규화 전] 최소값 : {x_train.min()}, 최대값 : {x_train.max()}')

# 데이터 정규화
x_train = x_train / x_train.max()

# 정규화 후 최소/최대값 확인
print(f'정규화 후] 최소값 : {x_train.min()}, 최대값 : {x_train.max()}')
# Out:
# 정규화 전] 최소값 : 0, 최대값 : 255
# 정규화 후] 최소값 : 0.0, 최대값 : 1.0

# %%
# test 셋에도 정규화 동일 적용
x_test = x_test / x_test.max()

# %%
# 변환 후 x_train 배열의 데이터 확인
x_train[0, 10:15, 10:15]
# Out:
# array([[0.00392157, 0.60392157, 0.99215686, 0.35294118, 0.        ],
#        [0.        , 0.54509804, 0.99215686, 0.74509804, 0.00784314],
#        [0.        , 0.04313725, 0.74509804, 0.99215686, 0.2745098 ],
#        [0.        , 0.        , 0.1372549 , 0.94509804, 0.88235294],
#        [0.        , 0.        , 0.        , 0.31764706, 0.94117647]])

# %% [markdown]
# 3-3 Flatten 레이어
# - 정규화를 하면 개별 데이터의 범위는 축소, 원본 배열의 형태는 그대로 유지
# - Dense 레이어 입력값: 1차원만 넣을 수 있음. -> 1차원으로 전처리

# %%
#reshape 사용
print(f'변경 전 shape : {x_train.shape}')
print(f'1D으로 shape 변경 후 : {x_train.reshape(60000, -1).shape}')
# Out:
# 변경 전 shape : (60000, 28, 28)
# 1D으로 shape 변경 후 : (60000, 784)

# %%
#Flatten 레이어를 사용
print(f'변경 전 shape : {x_train.shape}')
print(f'Flatten 적용 후 : {tf.keras.layers.Flatten()(x_train).shape}')
# Out:
# 변경 전 shape : (60000, 28, 28)
# Flatten 적용 후 : (60000, 784)

# %% [markdown]
# 3-4 활성화 함수

# %%
# Dense 레이어에 relu 활성화 함수를 적용한 경우
tf.keras.layers.Dense(128, activation='relu')
# Out:
# <Dense name=dense_13, built=False>

# %%
# Dense 레이어와 relu 활성화 함수 레이어를 별도 적용한 경우
model = tf.keras.Sequential([
        tf.keras.layers.Dense(128),
        tf.keras.layers.Activation('relu')
])

# %% [markdown]
# 3-5 입력과 출력
# - 첫 번째 레이어에 입력 데이터의 형태를 나타내는 input_shape 매개변수 지정하는 것이 일반적
# - 가장 마지막 레이어인 출력층: 분류해야할 클래스의 개수와 동일하게 지정해야함.

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28)),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),

        # 노드 = 10개(클래스 개수와 동일) = 마지막 출력층의 노드 개수
        tf.keras.layers.Dense(10, activation='softmax'),
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 출력층 노드 = 1인 경우, sigmoid
tf.keras.layers.Dense(1, activation = 'sigmoid')

# 출력층 노드 = 2개 이상인 경우, softmax
tf.keras.layers.Dense(10, activation = 'softmax')
# Out:
# <Dense name=dense_20, built=False>

# %% [markdown]
# 3-6 손실함수
# - 이진 분류기
#     - 출력층의 노드 개수: 1개
#       - activation = 'sigmoid'
#       - loss = 'binary_crossentropy'
#     - 출력층의 노드 개수: 2개 이상
#       - activation = 'softmax'
#       - loss
#         - y가 원핫 벡터인 경우 : 'categorical_crossentropy'
#         - y가 원핫 벡터가 아닌 경우 : 'sparse_categorical_crossentropy'

# %%
# 이진 분류(출력 노드 개수 = 1, sigmoid인 경우)
model.compile(loss = 'binary_crossentropy')

# %%
# y가 원핫 벡터인 경우
model.compile(loss = 'categorical_crossentropy')
# y가 원핫 벡터가 아닌 경우
model.compile(loss = 'sparse_categorical_crossentropy')

# %% [markdown]
# 3-7 옵티마이저
# - 손실을 낮추기 위해서 신경망의 가중치와 학습률이 같은 신경망의 속성을 변경하는데 사용되는 최적화 방법
# - Adam 많이 사용함.

# %%
# 클래스 인스턴스로 지정
# 클래스 인스턴스로 지정하는 경우 학습률(lr)과 같은 파라미터를 직접 설정할 수 있다.
adam = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=adam)

# 문자열로 지정
model.compile(optimizer='adam')

# %% [markdown]
# 3-8 평가지표
# - 분류 모델 평가지표: accuracy, auc, precision, recall
# - 리스트 형태로 하나 이상의 평가지표 지정 가

# %%
# 클래스 인스턴스로 지정
acc = tf.keras.metrics.SparseCategoricalAccuracy()

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=[acc])

# %%
# 문자열로 지정
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# 3-9 훈련

# %%
model.fit(x_train, y_train,
          # 검증 셋 지정
          validation_data = (x_test, y_test),
          epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8746 - loss: 0.4137 - val_accuracy: 0.9604 - val_loss: 0.1268
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - accuracy: 0.9701 - loss: 0.0958 - val_accuracy: 0.9688 - val_loss: 0.0959
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9810 - loss: 0.0625 - val_accuracy: 0.9741 - val_loss: 0.0776
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9858 - loss: 0.0459 - val_accuracy: 0.9755 - val_loss: 0.0816
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9884 - loss: 0.0361 - val_accuracy: 0.9750 - val_loss: 0.0830
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9900 - loss: 0.0322 - val_accuracy: 0.9716 - val_loss: 0.1050
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9907 - loss: 0.0274 - val_accuracy: 0.9790 - val_loss: 0.0744
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9937 - loss: 0.0192 - val_accuracy: 0.9780 - val_loss: 0.0873
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9946 - loss: 0.0172 - val_accuracy: 0.9779 - val_loss: 0.0987
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9939 - loss: 0.0184 - val_accuracy: 0.9808 - val_loss: 0.0881

# %% [markdown]
# 3-10 평가
# - evaluate() : compile 단계에서 지정한 손실(loss function)과 정확도(accuracy)를 순서대로 반환함.

# %%
# 검증
test_loss, test_acc = model.evaluate(x_test, y_test)

print('검증 셋 정확도 : ', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9769 - loss: 0.1104
# 검증 셋 정확도 :  0.9807999730110168

# %% [markdown]
# 3-11 예측
# - predict() 메소드에 새로운 이미지(데이터)를 넣어주면 예측 결과를 반환함.

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# 첫 번째 데이터에 대한 분류 예측 결과 출력
predictions[0]
# Out:
# array([2.9526420e-10, 4.0229966e-09, 3.0752936e-08, 3.1920729e-07,
#        1.4471459e-08, 2.0734026e-09, 2.5117252e-15, 9.9999899e-01,
#        4.0994572e-09, 6.4282955e-07], dtype=float32)

# %% [markdown]
# - numpy의 argmax를 활용하여 가장 높은 확률값을 가지는 클래스를 확인할 수 있음.

# %%
import numpy as np

# 0번 index에 대한 예측 클래스 출력
print(np.argmax(predictions[0]))

# 첫 10개 index에 대한 예측 클래스 출력
print(np.argmax(predictions[:10], axis=1))
# Out:
# 7
# [7 2 1 0 4 1 4 9 5 9]

# %%
# 데이터 시각화
import matplotlib.pyplot as plt
def get_one_result(idx):
  img, y_true, y_pred, confidence = x_test[idx], y_test[idx], np.argmax(predictions[idx]), 100*np.max(predictions[idx])
  return img, y_true, y_pred, confidence

# canvas 생성
fig, axes = plt.subplots(3, 5)
fig.set_size_inches(12, 10)
for i in range(15):
  ax = axes[i//5, i%5]
  img, y_true, y_pred, confidence = get_one_result(i)
  # imshow로 이미지 시각화
  ax.imshow(img, cmap = 'gray')
  ax.set_xticks([])
  ax.set_yticks([])
  ax.set_title(f'True : {y_true}')
  ax.set_xlabel(f'Prediction : {y_pred}\nConfidence : ({confidence:.2f} %)')
plt.tight_layout()
plt.show()
